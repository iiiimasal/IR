# %% [markdown]
# <a href="https://colab.research.google.com/github/iiiimasal/IR/blob/master/preprocessing_context_ipyn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
print(nltk.__version__)

import nltk
nltk.download('stopwords', download_dir='/usr/local/nltk_data')
import nltk
nltk.download('wordnet', download_dir='/usr/local/nltk_data')
# Out:
# 3.9.1
# [nltk_data] Downloading package stopwords to /usr/local/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /usr/local/nltk_data...
# True

# %%
# !pip install wikipedia-api
# Out:
# Collecting wikipedia-api
#   Downloading wikipedia_api-0.8.1.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from wikipedia-api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->wikipedia-api) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->wikipedia-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->wikipedia-api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->wikipedia-api) (2025.1.31)
# Building wheels for collected packages: wikipedia-api
#   Building wheel for wikipedia-api (setup.py) ... done
#   Created wheel for wikipedia-api: filename=Wikipedia_API-0.8.1-py3-none-any.whl size=15384 sha256=7093b4e8001b8001f88843e9d747f6e0c953152b3886c56f5592ffc7f7b885cb
#   Stored in directory: /root/.cache/pip/wheels/0b/0f/39/e8214ec038ccd5aeb8c82b957289f2f3ab2251febeae5c2860
# Successfully built wikipedia-api
# Installing collected packages: wikipedia-api
# Successfully installed wikipedia-api-0.8.1

# %%
import nltk
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import ssl

def preprocess_text(content):

    try:
        _create_unverified_https_context = ssl._create_unverified_context
    except AttributeError:
        pass
    else:
        ssl._create_default_https_context = _create_unverified_https_context

    # Ensure necessary NLTK data is downloaded
    nltk.download('stopwords', quiet=True)
    nltk.download('punkt', quiet=True)
    nltk.download('wordnet', quiet=True)

    # Tokenization
    tokens = word_tokenize(content)

    # Remove punctuation
    tokens = [word for word in tokens if word not in string.punctuation]

    # Lowercasing
    tokens = [word.lower() for word in tokens]

    # Removing stopwords
    stop_words = set(stopwords.words('english'))
    tokens_no_stopwords = [word for word in tokens if word not in stop_words]

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(word) for word in tokens_no_stopwords]

    return lemmatized_tokens

# %%
import requests
import wikipediaapi
import re
from urllib.parse import unquote  # To decode the URL

# Function to extract Wikipedia page title from URL
def extract_title_from_url(url):
    # Decode the URL to handle special characters like '%27' (apostrophe)
    decoded_url = unquote(url)
    # Extract title from a Wikipedia URL
    match = re.search(r"\/wiki\/(.+)$", decoded_url)
    if match:
        return match.group(1)
    else:
        return None

# Function to fetch Wikipedia content based on the page title
def get_wikipedia_content(page_title, lang="en"):
    user_agent = "MyWikipediaBot/1.0 (Contact: your_email@example.com)"
    wiki_wiki = wikipediaapi.Wikipedia(language=lang, user_agent=user_agent)

    page = wiki_wiki.page(page_title)
    if not page.exists():
        print(f"Page '{page_title}' not found!")
        return None

    return page.text  # Extract full text content

# URL of the raw text file on GitHub (which contains URLs of Wikipedia pages)
f = "https://raw.githubusercontent.com/iiiimasal/IR/master/source_file"

# Fetch the file containing URLs
response = requests.get(f)
if response.status_code == 200:
    urls = response.text.splitlines()  # Convert text into a list of URLs
    print(urls)
    # Loop through URLs and get content from Wikipedia
    for url in urls:
        print(f"Processing URL: {url}")
        title = extract_title_from_url(url)  # Extract the title from the URL
        if title:
            content = get_wikipedia_content(title)  # Fetch Wikipedia content
            if content:
                print(f"Content from {url}:")
                print(preprocess_text(content))

                print("="*100)  # Separator for readability
        else:
            print(f"Invalid Wikipedia URL: {url}")
else:
    print("Failed to fetch file:", response.status_code)
# Out:
# ['https://en.wikipedia.org/wiki/Harry_Potter_and_the_Philosopher%27s_Stone_(film)', 'https://en.wikipedia.org/wiki/Harry_Potter_and_the_Chamber_of_Secrets_(film)', 'https://en.wikipedia.org/wiki/Harry_Potter_and_the_
ards', 'add', 'visual', 'effect', 'film', "'s", 'budget', 'reportedly', '£75', '100', 'million', '150–200', 'million', 'harry', 'potter', 'order', 'phoenix', 'released', '2d', 'cinema', 'imax', 'format', 'united', 'state', '11', 'july', '2007', 'united', 'kingdom', '12', 'july', 'warner', 'bros.', 'picture', 'film', 'received', 'generally', 'positive', 'review', 'critic', 'nominated', 'many', 'award', 'including', 'bafta', 'award', 'best', 'production', 'design', 'special', 'visual', 'effect', 'worldwide', 'five-day', 'opening', '333', 'million', 'total', 'gross', '942', 'million', 'second-highest-grossing', 'film', '2007', 'noted', 'case', 'hollywood', 'accounting', 'warner', 'bros.', 'claimed', 'lost', '167', 'million', 'despite', 'total', 'gross', 'sequel', 'harry', 'potter', 'half-blood', 'prince', 'released', '2009', 'plot', 'staying', 'dursleys', 'harry', 'potter', 'dudley', 'attacked', 'dementors', 'harry', 'repels', 'using', 'patronus', 'spell', 'ministry', 'magic', 'detects', 'harry', 'using', 'magic', 'expels', 'hogwarts', 'though', 'later', 'exonerated', 'order', 'phoenix', 'secret', 'organisation', 'founded', 'albus', 'dumbledore', 'informs', 'harry', 'ministry', 'magic', 'attempting', 'stonewall', 'rumor', 'lord', 'voldemort', "'s", 'return', 'order', "'s", 'headquarters', 'harry', "'s", 'godfather', 'sirius', 'black', 'mention', 'voldemort', 'seek', 'object', 'previously', 'lacked', 'harry', 'belief', 'weapon', 'minister', 'magic', 'cornelius', 'fudge', 'appointed', 'dolores', 'umbridge', 'hogwarts', 'new', 'defence', 'dark', 'art', 'professor', 'umbridge', "'s", 'refusal', 'teach', 'defensive', 'spell', 'cause', 'harry', 'clash', 'harry', 'forced', 'write', 'line', '``', 'lying', "''", 'voldemort', 'magic', 'quill', 'etches', 'word', 'hand', 'writes', 'ron', 'hermione', 'outraged', 'harry', 'refuse', 'tell', 'dumbledore', 'distanced', 'harry', 'umbridge', 'gain', 'control', 'school', 'ron', 'hermione', 'help', 'harry', 'form', '``', 'dumbledore', "'s", 'army', "''", 'secret', 'group', 'teach', 'student', 'defensive', 'spell', 'umbridge', 'recruit', 'slytherins', 'inquisitorial', 'squad', 'spy', 'student', 'meanwhile', 'harry', 'cho', 'chang', 'develop', 'romantic', 'feeling', 'one', 'night', 'harry', 'envisions', 'arthur', 'weasley', 'attacked', 'ministry', 'seeing', 'attacker', "'s", 'perspective', 'concerned', 'voldemort', 'exploit', 'connection', 'harry', 'dumbledore', 'severus', 'snape', 'teach', 'harry', 'occlumency', 'defend', 'mind', 'voldemort', "'s", 'influence', 'lesson', 'harry', 'see', 'snape', "'s", 'memory', 'father', 'james', 'bullied', 'tormented', 'snape', 'school', 'connection', 'harry', 'voldemort', 'isolates', 'harry', 'friend', 'meanwhile', 'bellatrix', 'lestrange', 'sirius', "'s", 'deranged', 'death', 'eater', 'cousin', 'escape', 'azkaban', 'prison', 'along', 'nine', 'death', 'eater', 'hogwarts', 'umbridge', 'inquisitorial', 'squad', 'expose', 'dumbledore', "'s", 'army', 'dumbledore', 'falsely', 'accused', 'forming', 'escape', 'fudge' ...
# ====================================================================================================

# %%
def preprocess_persian_text(text):
    # 1. Normalize text
    text = normalizer.normalize(text)

    # 2. Tokenize
    tokens = word_tokenize(text)

    # 3. Remove stopwords
    tokens = [word for word in tokens if word not in stopwords and word not in punctuation]
    # 4. Lemmatization (reduce words to their base form)
    lemmatized_tokens = [lemmatizer.lemmatize(word) for word in tokens]

    return lemmatized_tokens  # Return processed tokens

# %%
from hazm import Normalizer, word_tokenize, Lemmatizer, stopwords_list
import string
# Initialize hazm tools
normalizer = Normalizer()
lemmatizer = Lemmatizer()
stopwords = set(stopwords_list())  # Load Persian stopwords
print(stopwords)
punctuation = set(string.punctuation)
# Out:
# {'دهه', 'خیلی', 'آقای', 'دانست', 'می\u200cگیرد', 'کرده_اند', 'بدون', 'کرده', 'برای', 'بخش', 'شان', 'بی', 'اگر', 'باز', 'نظیر', 'نباید', 'همین', 'پس', 'زیادی', 'گرفته', 'طور', 'نشست', 'تا', 'بهتر', 'کل', 'شده_اند', 'غیر', 'چیزی', 'تمامی', 'دهد', 'بودند', 'شما', 'آمده_است', 'بوده', 'گرفته_است', 'پنج', 'زیرا', 'سایر', 'حد', 'همان', 'داشتن', 'چهارم', 'متفاوت', 'می\u200cکند', 'کرده_است', 'با', 'سراسر', 'باشند', 'دارند', 'کنار', 'بین', 'و', 'بودن', 'بندی', 'سبب', 'کامل', 'بلکه', 'تو', 'حدود', 'ع', 'حالا', 'آمده', 'خودش', 'حالی', 'کنیم', 'علیه', 'یکدیگر', 'داریم', 'برداری', 'بار', 'دچار', 'می\u200cگویند', 'سوی', 'می\u200cکرد', 'یافته', 'می\u200cدهند', 'ولی', 'جمع', 'هنوز', 'ندارند', 'می\u200cکنند', 'کند', 'کنند', 'داده', 'گاه', 'دسته', 'عدم', 'خطر', 'می\u200cشود', 'کردم', 'شدن', 'آن', 'می', 'دور', 'می\u200cدهد', 'نظر', 'همه', 'مورد', 'مناسب', 'شمار', 'باید', 'لذا', 'بالا', 'اثر', 'گفته', 'شش', 'عالی', 'گروهی', 'کسی', 'می\u200cیابد', 'لحاظ', 'دو', 'قبل', 'دار', 'رشد', 'نخستین', 'سال\u200cهای', 'محسوب', 'آنچه', 'سهم', 'چگونه', 'رسید', 'بیش', 'آنجا', 'خواهد_شد', 'آنکه', 'کردند', 'من', 'اما', 'ساله', 'جدید', 'دیگری', 'تنها', 'پخش', 'تعداد', 'سی', 'این', 'خوب', 'داشته_است', 'می\u200cآید', 'اغلب', 'نیمه', 'باعث', 'چهار', 'ابتدا', 'می\u200cباشد', 'یافته_است', 'در', 'شروع', 'تاکنون', 'هستند', 'بسیار', 'روند', 'نزدیک', 'فکر', 'اکنون', 'می\u200cشوند', 'چون', 'داشته', 'نه', 'جایی', 'طی', 'است', 'هیچ', 'هنگام', 'سه', 'داشته_باشد', 'شده', 'مربوط', 'خصوص', 'پشت', 'کم', 'فرد', 'اینجا', 'راه', 'افرادی', 'بروز', 'ساز', 'براساس', 'ایشان', 'هر', 'یابد', 'تمام', 'کنید', 'حداقل', 'رو', 'صرف', 'گونه', 'ریزی', 'روبه', 'آیا', 'می\u200cکردند', 'وقتی', 'شامل', 'سازی', 'عهده', 'نمی\u200cشود', 'اولین', 'ویژه', 'حل', 'شدند', 'علاوه', 'خاطرنشان', 'هستیم', 'داشت', 'همچنین', 'خویش', 'اجرا', 'مواجه', 'کمی', 'طول', 'مهم', 'گیری', 'آنان', 'باشد', 'داد', 'یافت', 'دیگران', 'یک', 'گذاری', 'کدام', 'بسیاری', 'نیز', 'خاص', 'عین', 'شاید', 'آنها', 'بیشتری', 'جای', 'وارد', 'برخی', 'نبود', 'کنم', 'دهند', 'شود', 'نحوه', 'نوعی', 'کنندگان', 'فردی', 'جمعی', 'رسیدن', 'هم', 'می\u200cکنم', 'طرف', 'بیرون', 'فوق', 'حتی', 'دوم', 'می\u200cتواند', 'نیست', 'دوباره', 'چیز', 'می\u200cشد', 'شد', 'کاملا', 'تحت', 'خوبی', 'چرا', 'متر', 'می\u200cگوید', 'چند', 'سوم', 'شوند', 'گرفت', 'خواهد_بود', 'هایی', 'چه', 'اخیر', 'البته', 'جریان', 'امکان', 'می\u200cرود', 'اینکه', 'آوری', 'یعنی', 'پیدا', 'اول', 'زیر', 'مدت', 'کرد', 'یا', 'دادن', 'به', 'لازم', 'پیش', 'از', 'خواهد_کرد', 'موجب', 'طبق', 'نخست', 'کسانی', 'کرده_بود', 'دارد', 'جاری', 'ما', 'بعضی', 'نیستند', 'یکی', 'آورد', 'بنابراین', 'شخصی', 'تغییر', 'اند', 'بیشتر', 'کردن', 'سالهای', 'اش', 'حال', 'داده_است', 'می\u200cتوان', 'سعی', 'ممکن', 'باره', 'بعد', 'شده_است', 'متاسفانه', 'نیاز', 'همچنان', 'نوع', 'رفت', 'داشتند', 'دیگر', 'روش', 'مانند', 'که', 'داشته_باشند', 'امر', 'را', 'می\u200cرسد', 'پر', 'مثل', 'جا', 'وی', 'تعیین', 'زیاد', 'بود', 'کوچک', 'منظور', 'نسبت', 'بر', 'زاده', 'ندارد', 'بهترین', 'جز', 'گردد', 'ضمن', 'فقط', 'او', 'بخشی', 'همواره', 'بیان', 'گیرد', 'سمت', 'کننده', 'آخرین', 'تبدیل', 'دادند', 'دارای', 'گفت', 'می\u200cتوانند', 'برابر', 'همچون', 'شده_بود', 'سپس', 'بوده_است', 'می\u200cکنیم', 'مشخص', 'افراد', 'روی', 'ترتیب', 'پی', 'وگو', 'خود', 'بزرگ', 'درون', 'میان', 'تهیه', 'چنین', 'وجود', 'قابل', 'علت', 'کلی', 'همیشه', 'درباره', 'آمد', 'ناشی', 'جدی', 'کافی', 'افزود'}

# %%
import wikipediaapi
import requests

# Initialize Wikipedia API for Persian
user_agent = "your-application-name/1.0 (your-email@example.com)"
wiki = wikipediaapi.Wikipedia(language='fa', user_agent=user_agent)

# Function to fetch Wikipedia content
def get_wikipedia_persian_content(title):
    formatted_title = title.strip().replace(" ", "_")  # Remove spaces and replace with underscores
    page = wiki.page(formatted_title)

    if page.exists():
        return page.text  # Return full content
    else:
        print(f"Page not found for title: {title} (Formatted: {formatted_title})")
        return None

# URL of the raw text file on GitHub (which contains Wikipedia titles)
url = "https://raw.githubusercontent.com/iiiimasal/IR/master/source_file_persian"

# Fetch the file containing Wikipedia titles
response = requests.get(url)
if response.status_code == 200:
    titles = response.text.splitlines()  # Convert text into a list of titles
    print("Fetched Titles:", [repr(title) for title in titles])  # Show raw format for debugging

    # Loop through titles and fetch content from Wikipedia
    for title in titles:
        title = title.strip()  # Remove extra spaces
        if title:
            content = get_wikipedia_persian_content(title)
            if content:
                print(f"Content from {title}:")
                #print(content[:500])  # Print only the first 500 characters for preview
                print(preprocess_persian_text(content))

                print("="*100)
            else:
                print(f"Failed to fetch content from {title}")
        else:
            print("Invalid Wikipedia title (empty)")
else:
    print("Failed to fetch file:", response.status_code)
# Out:
# Fetched Titles: ["'هری پاتر و شاهزاده دورگه (فیلم)'", "'هری پاتر و یادگاران مرگ – قسمت اول'", "'بازی\\u200cهای گرسنگی (فیلم)'", "'دونده مارپیچ (فیلم)'", "'سنت\\u200cشکن (فیلم)'", "''"]
# Content from هری پاتر و شاهزاده دورگه (فیلم):
# ['هری', 'پاتر', 'شاهزاده', 'دورگه', 'انگلیسی', 'Harry', 'Potter', 'and', 'the', 'Half-Blood', 'Prince', 'فیلم', 'ژانر', 'ماجراجویانه', 'فانتزی', 'کارگردانی', 'دیوید', 'یتس', 'نویسندگی', 'استیو', 'کلاوز', 'اساس', 'رمانی', 'نام', 'جی', 'کی', 'رولینگ', '،', 'ساخته', 'شرکت', 'برادر', 'وارنر', '۱۵', 'ژوئیه', '۲۰۰۹', 'میلادی', 'اکران', 'عمومی', 'فیلم', 'ششمین', 'قسمت', 'مجموعه', 'فیلم', 'سینمایی', 'هری', 'پاتر', 'به\u200cشمار', '،', 'موفقیت', 'فروش', 'دید', 'منتقد', 'روبرو', 'هری', 'پاتر', 'شاهزاده', 'دورگه', '،', 'عنوان', 'پرفروشترین', 'فیلم', 'روز', 'اکران', 'دومین', 'فیلم', 'پرفروش', 'سال', '۲۰۰۹', 'آواتار', '۹۳۴', 'میلیون', 'دلار', 'فروش', '،', 'پنجاه', 'پنجمین', 'فیلم', 'پرفروش', 'تاریخ', 'داستان', 'قسمت', 'هری', 'پاتر', 'سال', 'ششم', 'هاگوارتز', 'تحصیل', 'هری', 'سال', 'تحصیلی', 'کلاس', 'خصوصی', 'دامبلدور', 'آن', 'مرور', 'بازبینی', 'خاطرات', 'لرد', 'سیاه', 'پرداخت#پرداز', '؛', 'بازیگر', 'دنیل', 'ردکلیف', 'نقش', 'هری', 'جیمز', 'پاتر', 'منتخب', 'مبارزه', 'لرد', 'ولدمورت', 'روپرت', 'گرین', 'نقش', 'رون', 'ویزلی', 'دوست', 'هری', 'پاتر', 'واتسون', 'نقش', 'هرماینی', 'گرنجر', 'دوست', 'هری', 'پاتر', 'مایکل', 'گمبون', 'نقش', 'آلبوس', 'دامبلدور', 'مدیر', 'مدرسه', 'هاگوارتز', 'جیم', 'برودبنت', 'نقش', 'هوریس', 'اسلاگهورن', 'معلم', 'آلن', 'ریکمن', 'نقش', 'سیو
شهر', 'دست', 'شده\u200cاست', '،', 'مجذوب', 'گروه', 'شجاعت', 'بوده\u200cاست', 'پدرش', 'اندرو', 'تونی', 'گلدوین', '،', 'همراه', 'رهبر', 'فرقه', 'فداکاری', '،', 'مارکوس', 'ایتن', 'ری', 'استیونسون', 'مجلس', 'کار', 'سال', '،', '۱۶', 'ساله', 'آزمایش', 'استعداد', 'سخت#سنج', 'تزریق', 'سرید#سر', 'انجام', 'قرار', 'گرفت#گیر', 'آزمون', 'آن', 'بگروهی', 'آن', 'نشان', 'آن', 'انتخاب', 'مراسم', 'انتخاب', 'راهنمایی', 'بیاتریس', 'آزمون', 'نظارت', 'زنی', 'شجاعت', 'نام', 'توری', 'مگ', 'کیو', 'گذراند#گذران', 'آزمایش', 'صفاتی', 'چندین', 'نشان', 'فداکاری', '،', 'دانش', 'شجاعت', '،', 'نمایانگر', 'ناهمتا', 'توری', 'فداکاری', 'عنوان', 'نتیجه', 'آزمون', 'ثبت', 'بیاتریس', 'نتیجه', 'واقعی', 'راز', 'نگه', 'توری', 'ناهمتا', '،', 'به\u200cطور', 'مستقل', 'هرگونه', 'دستگاری', 'فیزیکی', 'توسط', 'دولت', 'اعمال', 'حکومت', 'توانست#توان', 'کنترل', 'دلیل', 'تهدید', 'نظم', 'اجتماعی', 'حساب', 'آمد#آی', 'روز', 'مراسم', 'انتخاب', '،', 'برادر', 'بیاتریس', '،', 'کیلب', 'انسل', 'الگورت', 'گروه', 'دانش', 'انتخاب', '،', 'بیاتریس', 'دودلی', 'شجاعت', 'انتخاب', 'مراسم', '،', 'بیاتریس', 'کریستینا', 'زو', 'کراویتز', 'ال', 'کریستین', 'مدسن', '،', 'نفر', 'صداقت', '،', 'ویل', 'بن', 'للوید-هیوز', '،', 'گروه', 'دانش', 'همگی', 'شجاعت', 'انتخاب', 'کرد#کن', 'آشنا', 'تازه', 'واردان', 'شجاعت', '،', 'آزمون', 'قبیل', 'پریدن', 'قطاری', 'حرکت', 'حداکثر', 'سرعت', 'پرش', 'ساختمان', 'بلند', 'داخل', 'حفره', 'گرفت#گیر', 'آزمون', '،', 'تازه\u200cوارد', '،', 'اریک', 'کور ...
# ====================================================================================================
# Invalid Wikipedia title (empty)

# %%
# !pip install hazm
# Out:
# Requirement already satisfied: hazm in /usr/local/lib/python3.11/dist-packages (0.10.0)
# Requirement already satisfied: fasttext-wheel<0.10.0,>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from hazm) (0.9.2)
# Requirement already satisfied: flashtext<3.0,>=2.7 in /usr/local/lib/python3.11/dist-packages (from hazm) (2.7)
# Requirement already satisfied: gensim<5.0.0,>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from hazm) (4.3.3)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.11/dist-packages (from hazm) (3.9.1)
# Requirement already satisfied: numpy==1.24.3 in /usr/local/lib/python3.11/dist-packages (from hazm) (1.24.3)
# Requirement already satisfied: python-crfsuite<0.10.0,>=0.9.9 in /usr/local/lib/python3.11/dist-packages (from hazm) (0.9.11)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.2.2 in /usr/local/lib/python3.11/dist-packages (from hazm) (1.6.1)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.11/dist-packages (from fasttext-wheel<0.10.0,>=0.9.2->hazm) (2.13.6)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from fasttext-wheel<0.10.0,>=0.9.2->hazm) (75.1.0)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from gensim<5.0.0,>=4.3.1->hazm) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim<5.0.0,>=4.3.1->hazm) (7.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk<4.0.0,>=3.8.1->hazm) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk<4.0.0,>=3.8.1->hazm) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk<4.0.0,>=3.8.1->hazm) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk<4.0.0,>=3.8.1->hazm) (4.67.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.2.2->hazm) (3.6.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim<5.0.0,>=4.3.1->hazm) (1.17.2)
